# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from airflow.operators.bash import BashOperator

from datetime import datetime, timedelta
import sys
from utils import *
from constants import *
# Out:
# [2025-02-14 18:02:45,267] {utils.py:145} INFO - Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2025-02-14 18:02:45,269] {utils.py:157} INFO - NumExpr defaulting to 8 threads.

# %%
def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
print(DB_PATH)
print(DB_FILE_NAME)
print(DB_FILE_MLFLOW)
print(FILE_PATH)
print(TRACKING_URI)
print(MODEL_NAME)
print(STAGE)
print(EXPERIMENT)
print(ONE_HOT_ENCODED_FEATURES)
print(FEATURES_TO_ENCODE)
# Out:
# /home/airflow/dags/Lead_scoring_data_pipeline/
# lead_scoring_data_cleaning.db
# /home/airflow/dags/Lead_scoring_training_pipeline/Lead_scoring_mlflow_production.db
# /home/Assignment/03_inference_pipeline/scripts/
# http://0.0.0.0:6006
# LightGBM
# Production
# Lead_scoring_mlflow_production
# ['total_leads_droppped', 'referred_lead', 'city_tier_1.0', 'city_tier_2.0', 'city_tier_3.0', 'first_platform_c_Level0', 'first_platform_c_Level3', 'first_platform_c_Level7', 'first_platform_c_Level1', 'first_platform_c_Level2', 'first_platform_c_Level8', 'first_platform_c_others', 'first_utm_medium_c_Level0', 'first_utm_medium_c_Level2', 'first_utm_medium_c_Level6', 'first_utm_medium_c_Level3', 'first_utm_medium_c_Level4', 'first_utm_medium_c_Level9', 'first_utm_medium_c_Level11', 'first_utm_medium_c_Level5', 'first_utm_medium_c_Level8', 'first_utm_medium_c_Level20', 'first_utm_medium_c_Level13', 'first_utm_medium_c_Level30', 'first_utm_medium_c_Level33', 'first_utm_medium_c_Level16', 'first_utm_medium_c_Level10', 'first_utm_medium_c_Level15', 'first_utm_medium_c_Level26', 'first_utm_medium_c_Level43', 'first_utm_medium_c_others', 'first_utm_source_c_Level2', 'first_utm_source_c_Level0', 'first_utm_source_c_Level7', 'first_utm_source_c_Level4', 'first_utm_source_c_Level6', 'first_utm_source_c_Level16', 'first_utm_source_c_Level5', 'first_utm_source_c_Level14', 'first_utm_source_c_others']
# ['city_tier', 'first_platform_c', 'first_utm_medium_c', 'first_utm_source_c']

# %%
encode_features()

# %%
get_models_prediction()

# %%
prediction_ratio_check()

# %%
input_features_check()
# Out:
# All the models input are present
